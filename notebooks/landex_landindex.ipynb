# %%
# !pip install --upgrade plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 32.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.5.0
#     Uninstalling plotly-5.5.0:
#       Successfully uninstalled plotly-5.5.0
# ...

# %%
import pandas as pd
import plotly.express as px
import numpy as np

df = pd.read_csv('https://raw.githubusercontent.com/kaljuvee/landindex/master/notebooks/data/maaamet_farm_forest_2021.csv')
df.rename(columns={'statistic': 'land_type', 'total_price': 'total_volume_eur', 'price_per_unit_average': 'avg_price_eur'}, inplace=True)

# last year data frame
ldf = df[df['year'] == 2020]

print('full set:', df.shape)
print('2020 data:', ldf.shape)
# Out:
# full set: (2142, 14)
# 2020 data: (121, 14)

# %%
ldf.head()
# Out:
#         land_type         county  year          region  number  average_area  \
# 1114  Forest land  Harju maakond  2020      Anija vald      13           8.9
# 1115  Forest land  Harju maakond  2020      Harku vald       5           6.7
# 1116  Forest land  Harju maakond  2020  Jõelähtme vald      12           5.4
# 1117  Forest land  Harju maakond  2020      Kiili vald       5           6.8
# 1118  Forest land  Harju maakond  2020       Kose vald      34          19.3
#
#       total_volume_eur  price_min  price_max  price_per_unit_min  \
# 1114            388016       3500      87150             1166.67
# 1115            274692      11200      88150             1679.16
# 1116            246209       1000      65000              222.72
# 1117            125563      16980      38750             2355.06
# 1118           3221378       1000    2000000              120.63
#
#       price_per_unit_max  price_per_unit_median  avg_price_eur  \
# ...

# %% [markdown]
# # Total Historical Sales Volume by Land Type

# %%
fig = px.bar(df, x='year', y='total_volume_eur',
             hover_data=['year', 'avg_price_eur', 'total_volume_eur', 'county', 'region'], color='land_type',
             labels={'avg_price_eur':'Average price (EUR per hectar)'}, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Relative price of land by region

# %%
fig = px.treemap(ldf, path=['land_type', 'county', 'region'], values='total_volume_eur',
                  color='avg_price_eur', hover_data=['region'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(ldf['avg_price_eur'], weights=ldf['total_volume_eur']))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Are larger plots more expensive? Average price vs average plot size

# %%
fig = px.scatter(ldf, x="average_area", y="avg_price_eur", color="county",
                 size='total_volume_eur', hover_data=['region'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Are larger art works more expensive? The relationship between the dimensions of an art work and its price

# %%
df.head()
# Out:
#      statistic            county  year             region  number  \
# 0  Forest land     Harju maakond  2000       Kuusalu vald       6
# 1  Forest land      Hiiu maakond  2000       Hiiumaa vald      58
# 2  Forest land  Ida-Viru maakond  2000     Alutaguse vald      16
# 3  Forest land  Ida-Viru maakond  2000         Jõhvi vald       5
# 4  Forest land  Ida-Viru maakond  2000  Narva-Jõesuu linn       5
#
#    average_area  total_price  price_min  price_max  price_per_unit_min  \
# 0           8.6        48381        767      12782              105.35
# 1          14.6       462239        639     100341               72.71
# 2          19.2       335344        639      76694              104.77
# 3           8.9        20068       1087      12782              262.44
# 4          39.8        74227        942      54325              103.74
#
#    price_per_unit_max  price_per_unit_median  price_per_unit_average  \
# ...
